# %% [markdown]
# <a href="https://colab.research.google.com/github/anajovanoviic/polyps-1/blob/master/polyps_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# %cd '/content/drive/My Drive/'
# Out:
# /content/drive/My Drive

# %%
# %cd 'Master/polyp-seg-idiot-dev-original+additional-features-by-Ana'
# Out:
# /content/drive/My Drive/Master/polyp-seg-idiot-dev-original+additional-features-by-Ana

# %%
# %pwd
# Out:
# '/content/drive/My Drive'

# %%
# %cd polyps-1
# Out:
# /content/drive/My Drive/polyps-1

# %%
# !pip install imshowtools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %% [markdown]
# # **Training on original data without augmentation**

# %%
# %run train.py
# Out:
# Epoch 1/50
# 62/62 [==============================] - 96s 1s/step - loss: 0.5548 - acc: 0.7632 - recall_1: 0.6027 - precision_1: 0.2267 - iou: 0.1117 - val_loss: 0.6833 - val_acc: 0.6778 - val_recall_1: 0.1945 - val_precision_1: 0.0639 - val_iou: 0.0755 - lr: 1.0000e-04
# Epoch 2/50
# 62/62 [==============================] - 7s 110ms/step - loss: 0.4142 - acc: 0.9019 - recall_1: 0.4877 - precision_1: 0.4936 - iou: 0.1374 - val_loss: 0.6002 - val_acc: 0.9007 - val_recall_1: 7.0236e-04 - val_precision_1: 0.0052 - val_iou: 0.0745 - lr: 1.0000e-04
# Epoch 3/50
# 62/62 [==============================] - 8s 134ms/step - loss: 0.3514 - acc: 0.9260 - recall_1: 0.4967 - precision_1: 0.6577 - iou: 0.1603 - val_loss: 0.4846 - val_acc: 0.9108 - val_recall_1: 1.9986e-04 - val_precision_1: 0.0111 - val_iou: 0.0704 - lr: 1.0000e-04
# Epoch 4/50
# ...

# %%
# %run augmentation.py
# Out:
# Images: 612 - Masks: 612
# PNG/Original/1.png PNG/groundTruth/1.png
# PNG/Original/10.png PNG/groundTruth/10.png
# PNG/Original/100.png PNG/groundTruth/100.png
# PNG/Original/101.png PNG/groundTruth/101.png
# PNG/Original/102.png PNG/groundTruth/102.png
# PNG/Original/103.png PNG/groundTruth/103.png
# PNG/Original/104.png PNG/groundTruth/104.png
# PNG/Original/105.png PNG/groundTruth/105.png
# PNG/Original/106.png PNG/groundTruth/106.png
# PNG/Original/107.png PNG/groundTruth/107.png
# Train: 490 - 490
# Valid: 61 - 61
# Test : 61 - 61
#   0%|          | 0/490 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1613: FutureWarning: This class has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/albumentations/augmentations/transforms.py:1639: FutureWarning: RandomContrast has been deprecated. Please use RandomBrightnessContrast
#   warnings.warn(
# ...

# %%
# !git clone https://github.com/anajovanoviic/polyps-1.git
# Out:
# Cloning into 'polyps-1'...
# remote: Enumerating objects: 4930, done.
# remote: Counting objects: 100% (4930/4930), done.
# remote: Compressing objects: 100% (4925/4925), done.
# remote: Total 4930 (delta 6), reused 4925 (delta 3), pack-reused 0
# Receiving objects: 100% (4930/4930), 1.05 MiB | 8.77 MiB/s, done.
# Resolving deltas: 100% (6/6), done.
# Updating files: 100% (6381/6381), done.
# Filtering content: 100% (6368/6368), 325.74 MiB | 1.40 MiB/s, done.
# fatal: cannot exec '/content/drive/My Drive/polyps-1/.git/hooks/post-checkout': Permission denied

# %%
# %pwd
# Out:
# '/content/drive/My Drive'

# %%
# %cd /content/drive/MyDrive/polyps-1
# Out:
# /content/drive/MyDrive/polyps-1

# %%
# !pip install imshowtools
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !git fetch

# %%
# !git pull
# Out:
# Already up to date.

# %% [markdown]
# # **Training on augmented data**

# %%
# %run train_aug.py
# Out:
# Train: 2450 - 2450
# Valid: 61 - 61
# Epoch 1/50
# 307/307 [==============================] - 48s 110ms/step - loss: 0.4428 - acc: 0.8601 - recall_1: 0.4196 - precision_1: 0.3260 - iou: 0.1112 - val_loss: 0.3938 - val_acc: 0.9121 - val_recall_1: 4.0828e-04 - val_precision_1: 0.0948 - val_iou: 0.0652 - lr: 1.0000e-04
# Epoch 2/50
# 307/307 [==============================] - 33s 107ms/step - loss: 0.3313 - acc: 0.9051 - recall_1: 0.3567 - precision_1: 0.5110 - iou: 0.1204 - val_loss: 0.2971 - val_acc: 0.9255 - val_recall_1: 0.1821 - val_precision_1: 0.8531 - val_iou: 0.1062 - lr: 1.0000e-04
# Epoch 3/50
# 307/307 [==============================] - 34s 111ms/step - loss: 0.2821 - acc: 0.9161 - recall_1: 0.4207 - precision_1: 0.5933 - iou: 0.1433 - val_loss: 0.2536 - val_acc: 0.9299 - val_recall_1: 0.2494 - val_precision_1: 0.8440 - val_iou: 0.1261 - lr: 1.0000e-04
# Epoch 4/50
# ...

# %% [markdown]
# # **Hyperparameter optimization**

# %%
# %run hyperparam_opt.py
# Out:
# Epoch 1/10
# 62/62 [==============================] - 22s 136ms/step - loss: 0.7236 - acc: 0.6170 - recall_2: 0.6608 - precision_2: 0.1542 - iou: 0.0979 - val_loss: 0.6725 - val_acc: 0.8961 - val_recall_2: 0.0471 - val_precision_2: 0.1688 - val_iou: 0.0764 - lr: 1.0000e-04
# Epoch 2/10
# 62/62 [==============================] - 7s 116ms/step - loss: 0.4889 - acc: 0.8793 - recall_2: 0.2086 - precision_2: 0.3117 - iou: 0.0993 - val_loss: 0.5806 - val_acc: 0.9079 - val_recall_2: 0.0013 - val_precision_2: 0.0239 - val_iou: 0.0731 - lr: 1.0000e-04
# Epoch 3/10
# 62/62 [==============================] - 8s 131ms/step - loss: 0.4368 - acc: 0.9042 - recall_2: 0.2355 - precision_2: 0.5063 - iou: 0.1055 - val_loss: 0.4917 - val_acc: 0.9113 - val_recall_2: 0.0024 - val_precision_2: 0.1426 - val_iou: 0.0743 - lr: 1.0000e-04
# Epoch 4/10
# ...
